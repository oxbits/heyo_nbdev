# %%
#| hide
from heyo_nbdev.core import *

# %% [markdown]
# # heyo_nbdev
#
# > heyo_nbdev

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install heyo_nbdev in Development mode

# %% [markdown]
# ```sh
# # make sure heyo_nbdev package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to heyo_nbdev
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/oxbits/heyo_nbdev.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c oxbits heyo_nbdev
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install heyo_nbdev
# ```
#
#
# [repo]: https://github.com/oxbits/heyo_nbdev
# [docs]: https://oxbits.github.io/heyo_nbdev/
# [pypi]: https://pypi.org/project/heyo_nbdev/
# [conda]: https://anaconda.org/oxbits/heyo_nbdev

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/oxbits/heyo_nbdev
# [docs]: https://oxbits.github.io/heyo_nbdev/
# [pypi]: https://pypi.org/project/heyo_nbdev/
# [conda]: https://anaconda.org/oxbits/heyo_nbdev

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
